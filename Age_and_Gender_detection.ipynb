# %% [markdown]
# <a href="https://colab.research.google.com/github/snehasamanta/Age-and-Gender-Prediction/blob/main/Age_and_Gender_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data source: https://www.kaggle.com/jangedoo/utkface-new

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/datasets/archive.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: utkface_aligned_cropped/crop_part1/34_1_0_20170109004755204.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_0_20170111182452832.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_1_20170103230340961.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_1_20170104011329697.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_1_20170104165020320.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_1_20170108230211421.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_2_20170104022134829.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_2_20170104023010725.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_2_20170104172537171.jpg.chip.jpg
#   inflating: utkface_aligned_cropped/crop_part1/34_1_2_20170104201443273.jpg.chip.jpg
# ...

# %%
fldr="/content/UTKFace"

# %%
import os
files=os.listdir(fldr)

files
# Out:
# ['24_1_3_20170119165930967.jpg.chip.jpg',
#  '54_0_0_20170111171747448.jpg.chip.jpg',
#  '40_0_1_20170116203957000.jpg.chip.jpg',
#  '23_1_0_20170116211903141.jpg.chip.jpg',
#  '25_1_1_20170112205059883.jpg.chip.jpg',
#  '28_0_0_20170117180520264.jpg.chip.jpg',
#  '26_0_3_20170116232725357.jpg.chip.jpg',
#  '27_1_2_20170104020735627.jpg.chip.jpg',
#  '37_1_1_20170114024523051.jpg.chip.jpg',
#  '1_0_0_20170109191725028.jpg.chip.jpg',
#  '4_0_4_20161221202651241.jpg.chip.jpg',
#  '25_1_0_20170103180835288.jpg.chip.jpg',
#  '29_0_3_20170117180744344.jpg.chip.jpg',
#  '50_0_3_20170105172943629.jpg.chip.jpg',
#  '26_1_2_20170104020230700.jpg.chip.jpg',
#  '21_0_1_20170113133118839.jpg.chip.jpg',
#  '61_0_1_20170113175551340.jpg.chip.jpg',
#  '96_1_0_20170110161321170.jpg.chip.jpg',
#  '38_1_0_20170105170148788.jpg.chip.jpg',
#  '56_1_0_20170110141232209.jpg.chip.jpg',
#  '56_1_0_20170110175738208.jpg.chip.jpg',
#  '34_0_4_20170117130526488.jpg.chip.jpg',
# ...

# %%
import cv2
ages=[]
genders=[]
images=[]

for fle in files:
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  total=fldr+'/'+fle
  print(total)
  image=cv2.imread(total)

  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image= cv2.resize(image,(48,48))
  images.append(image)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/UTKFace/86_0_0_20170111223837209.jpg.chip.jpg
# /content/UTKFace/61_0_0_20170117194413929.jpg.chip.jpg
# /content/UTKFace/47_0_0_20170105173116787.jpg.chip.jpg
# /content/UTKFace/26_1_3_20170117153630883.jpg.chip.jpg
# /content/UTKFace/52_0_0_20170116192914190.jpg.chip.jpg
# /content/UTKFace/90_0_2_20170110183643228.jpg.chip.jpg
# /content/UTKFace/32_1_2_20170116185951847.jpg.chip.jpg
# /content/UTKFace/90_0_0_20170111205657119.jpg.chip.jpg
# /content/UTKFace/29_1_4_20170117202752934.jpg.chip.jpg
# /content/UTKFace/75_0_1_20170117183723984.jpg.chip.jpg
# /content/UTKFace/16_0_0_20170110232111509.jpg.chip.jpg
# /content/UTKFace/28_1_1_20170117180712098.jpg.chip.jpg
# /content/UTKFace/32_1_1_20170116002032659.jpg.chip.jpg
# /content/UTKFace/32_1_2_20170104170327891.jpg.chip.jpg
# /content/UTKFace/24_0_0_20170117150104363.jpg.chip.jpg
# /content/UTKFace/26_0_1_20170116205301942.jpg.chip.jpg
# ...

# %%
for fle in files:
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(images[24])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F559BA9AF90>

# %%
print(ages[24])
print(genders[24])
# Out:
# 1
# 0

# %%
cv2_imshow(images[100])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F559BA9AF90>

# %%
print(ages[100])
print(genders[100])
# Out:
# 45
# 0

# %%
import numpy as np
images_f=np.array(images)
genders_f=np.array(genders)
ages_f=np.array(ages)

# %%
np.save(fldr+'image.npy',images_f)
np.save(fldr+'gender.npy',genders_f)
np.save(fldr+'age.npy',ages_f)

# %%
values, counts = np.unique(genders_f, return_counts=True)
print(counts)
# Out:
# [12391 11317]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male', 'Female']
values=[4372,5047]
ax.bar(gender,values)
plt.show()

# %%
values, counts = np.unique(ages_f, return_counts=True)
print(counts)
# Out:
# [1123  482  289  273  196  131  139  263  166  156   65  130   81  157
#   177  247  158  262   98  284  346  395  426  859  734 2197  615  918
#   570  724  350  664  143  409  880  483  293  325  266  526  132  266
#   157  100  440  153  170  153  148  381  138  232  241  353  268  236
#    97  271   82  293  161  125  103   50  259   77   94  100   56  147
#    33   98   63   32  148   58   28   69   23  133   22   40   18   24
#   155   35   10   34   33   82    2   13    5    9   17    9   11    2
#     1    5    5    1    3    4]

# %%
val=values.tolist()
cnt=counts.tolist()

# %%
plt.plot(counts)
plt.xlabel('ages')
plt.ylabel('distribution')
plt.show()

# %%
labels=[]

i=0
while i<len(ages):
  label=[]
  label.append([ages[i]])
  label.append([genders[i]])
  labels.append(label)
  i+=1

# %%
images_f_2=images_f/255
labels_f=np.array(labels)
images_f_2.shape
# Out:
# (23708, 48, 48, 3)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(images_f_2, labels_f,test_size=0.25)

# %%
Y_train_2=[Y_train[:,1],Y_train[:,0]]
Y_test_2=[Y_test[:,1],Y_test[:,0]]

# %% [markdown]
# # Model

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten,BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D,Conv2D
from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def Convolution(input_tensor,filters):
    
    x = Conv2D(filters=filters,kernel_size=(3, 3),padding = 'same',strides=(1, 1),kernel_regularizer=l2(0.001))(input_tensor)
    x = Dropout(0.1)(x)
    x= Activation('relu')(x)

    return x
def model(input_shape):
  inputs = Input((input_shape))
  
  conv_1= Convolution(inputs,32)
  maxp_1 = MaxPooling2D(pool_size = (2,2)) (conv_1)
  conv_2 = Convolution(maxp_1,64)
  maxp_2 = MaxPooling2D(pool_size = (2, 2)) (conv_2)
  conv_3 = Convolution(maxp_2,128)
  maxp_3 = MaxPooling2D(pool_size = (2, 2)) (conv_3)
  conv_4 = Convolution(maxp_3,256)
  maxp_4 = MaxPooling2D(pool_size = (2, 2)) (conv_4)
  flatten= Flatten() (maxp_4)
  dense_1= Dense(64,activation='relu')(flatten)
  dense_2= Dense(64,activation='relu')(flatten)
  drop_1=Dropout(0.2)(dense_1)
  drop_2=Dropout(0.2)(dense_2)
  output_1= Dense(1,activation="sigmoid",name='sex_out')(drop_1)
  output_2= Dense(1,activation="relu",name='age_out')(drop_2)
  model = Model(inputs=[inputs], outputs=[output_1,output_2])
  model.compile(loss=["binary_crossentropy","mae"], optimizer="Adam",
	metrics=["accuracy"])
  
  return model

# %%
Model=model((48,48,3))

# %%
Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 48, 48, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 48, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 48, 48, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 32)   0           activation[0][0]
# ...

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
fle_s='/content/drive/MyDrive/datasets/Age_sex_detection.h5'
checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
History=Model.fit(X_train,Y_train_2,batch_size=64,validation_data=(X_test,Y_test_2),epochs=10,callbacks=[callback_list])
# Out:
# Epoch 1/10
# 278/278 [==============================] - 150s 534ms/step - loss: 18.5413 - sex_out_loss: 0.7482 - age_out_loss: 17.5866 - sex_out_accuracy: 0.5153 - age_out_accuracy: 0.0468 - val_loss: 17.5560 - val_sex_out_loss: 0.6881 - val_age_out_loss: 16.7158 - val_sex_out_accuracy: 0.5261 - val_age_out_accuracy: 0.0488
#
# Epoch 00001: val_loss improved from inf to 17.55599, saving model to /content/drive/MyDrive/datasets/Age_sex_detection.h5
# Epoch 2/10
# 278/278 [==============================] - 150s 541ms/step - loss: 15.1306 - sex_out_loss: 0.6750 - age_out_loss: 14.2953 - sex_out_accuracy: 0.5651 - age_out_accuracy: 0.0467 - val_loss: 12.2702 - val_sex_out_loss: 0.5810 - val_age_out_loss: 11.4641 - val_sex_out_accuracy: 0.7191 - val_age_out_accuracy: 0.0488
#
# Epoch 00002: val_loss improved from 17.55599 to 12.27020, saving model to /content/drive/MyDrive/datasets/Age_sex_detection.h5
# Epoch 3/10
# ...

# %%
Model.evaluate(X_test,Y_test_2)
# Out:
# 186/186 [==============================] - 11s 57ms/step - loss: 10.3069 - sex_out_loss: 0.3475 - age_out_loss: 9.5519 - sex_out_accuracy: 0.8487 - age_out_accuracy: 0.0486
# [10.306878089904785,
#  0.3475383520126343,
#  9.551888465881348,
#  0.8486586809158325,
#  0.048591192811727524]

# %%
pred=Model.predict(X_test)

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,wspace=0.35)

# %%
plt.plot(History.history['sex_out_accuracy'])
plt.plot(History.history['val_sex_out_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# # For age

# %%
fig, ax = plt.subplots()
ax.scatter(Y_test_2[1], pred[1])
ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %% [markdown]
# # For gender

# %%
i=0
Pred_l=[]
while(i<len(pred[0])):

  Pred_l.append(int(np.round(pred[0][i])))
  i+=1

# %%
from sklearn.metrics import confusion_matrix 

from sklearn.metrics import classification_report

# %%
classification_report(Y_test_2[0], Pred_l)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.85      0.86      0.86      3118\n           1       0.84      0.84      0.84      2809\n\n    accuracy                           0.85      5927\n   macro avg       0.85      0.85      0.85      5927\nweighted avg       0.85      0.85      0.85      5927\n'

# %%
confusion_matrix(Y_test_2[0], Pred_l)
# Out:
# array([[2679,  439],
#        [ 458, 2351]])

# %%
import seaborn as sns

sns.heatmap(confusion_matrix(Y_test_2[0], Pred_l), annot=True,fmt='g')

# %%
def test_image(ind,images_f,images_f_2,Model):
  cv2_imshow(images_f[ind])
  image_test=images_f_2[ind]
  pred_1=Model.predict(np.array([image_test]))
  #print(pred_1)
  sex_f=['Male','Female']
  age=int(np.round(pred_1[1][0]))
  sex=int(np.round(pred_1[0][0]))
  print("Predicted Age: "+ str(age))
  print("Predicted Sex: "+ sex_f[sex])

# %%
test_image(24,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F5544172650>
# Predicted Age: 1
# Predicted Sex: Female
